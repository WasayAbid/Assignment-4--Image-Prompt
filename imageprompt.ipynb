# %% [markdown]
# # Import Google Generative AI

# %%
import google.generativeai as genai

# %% [markdown]
# # Reads Gemini Api Key

# %%
from dotenv import load_dotenv
import os

load_dotenv()  

GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# # Load The image

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open('airplane.jpg')
image_path = "airplane.jpg"  

plt.imshow(image)

print(image)
with open(image_path, "rb") as image_file:
    image_data = image_file.read()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=279x180 at 0x144751E7B60>

# %% [markdown]
# # Perform Api call to generate text according to the image data

# %%
import base64



model = genai.GenerativeModel(model_name="gemini-1.5-pro")

prompt = "Caption this image."

response = model.generate_content(
    [
        {
            "mime_type": "image/jpeg",
            "data": base64.b64encode(image_data).decode("utf-8"),
        },
        prompt,
    ]
)

# Display the response
print(">" + response.text)
# Out:
# >Here are a few caption options for the image of a plane flying at sunset:
#
# **Short & Sweet:**
#
# * Sunset takeoff.
# * Soaring into the sunset.
# * Up in the clouds.
# * Golden hour flight.
# * Dreamy skies.
#
# **More Descriptive:**
#
# * An airplane silhouetted against a vibrant sunset sky, soaring above a layer of colorful clouds.
# * The beauty of flight, captured as the sun dips below the horizon.
# * A breathtaking view from above as the plane ascends into the warm glow of sunset.
# * Traveling towards tomorrow, bathed in the golden light of the setting sun.
# * Peaceful journey above the clouds, with the sky ablaze in a symphony of colors.
#
# **Evocative:**
#
# * Chasing dreams among the clouds.
# * The world shrinks below as the sky expands above.
# * A moment of tranquility amidst the journey.
# * Where the earth meets the sky, painted by the setting sun.
# * The promise of adventure on the horizon.
#
#
# Choose the caption that best suits your intended tone and audience.
